# %%
from bs4 import BeautifulSoup as bs
import lxml
import nltk
import os
import string

nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import pandas as pd

df = pd.read_json("people.json")
from nltk.classify.scikitlearn import SklearnClassifier
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
import numpy as np
np.random.seed(400)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jason\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jason\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def extract_info(filepath):
    dictionary_of_interest = {}

    with open(filepath,"r",encoding="utf8") as file:
            
        content = file.readlines()
        content = "".join(content)
        
        bs_content = bs(content, "lxml")

        unique_id = bs_content.find("tei").attrs["xml:id"]

        letter_details = bs_content.find_all("correspaction")

        for deets in letter_details:

            if deets.attrs["type"] == "sent":

                try:
                    dictionary_of_interest["unique_id"] = unique_id
                    dictionary_of_interest["sender"] = deets.persname.text

                except AttributeError:
                    dictionary_of_interest["reciever"] = deets.orgname.text

                if "when" in list(deets.date.attrs.keys()):
                    dictionary_of_interest["date"] = deets.date.attrs["when"]

                try:
                    dictionary_of_interest["sender_bio"] = deets.persname.attrs["key"]
                except AttributeError:
                    dictionary_of_interest["sender_bio"] = "None Available"
                except KeyError:
                    dictionary_of_interest["sender_bio"] = "None Available"
                    
            if deets.attrs["type"] == "received":
                
                try:
                    dictionary_of_interest["reciever"] = deets.persname.text
                except AttributeError:
                    dictionary_of_interest["reciever"] = deets.orgname.text
                    
                try:
                    dictionary_of_interest["reciever_bio"] = deets.persname.attrs["key"]
                except AttributeError:
                    dictionary_of_interest["reciever_bio"] = "None Available"
                except KeyError:
                    dictionary_of_interest["reciever_bio"] = "None Available"
                    
        try:
            free_text = bs_content.find_all("div",{"type":"transcription"})[0].p.text
        except AttributeError:
#             print(bs_content) 
            free_text = ""

        # cleaning of the data
        free_text = free_text.lower().translate(str.maketrans('','',string.punctuation))
        go_away_chars = ['’', '“', '‘', '〈', '〉', '–', '♂', '…', '♀', '〈', '〉', '☿', '§', '⊙', '▵', '∴', '„', '✓']
        for char in go_away_chars:
            free_text = str.replace(free_text, char, "_")
        dictionary_of_interest["body"] = free_text

        file.close()

    return dictionary_of_interest

def generate_feature_data(free_text,feature_set):
    
    feature_bools = []
    
    for word in feature_set:
        feature_bools.append(1*(word in free_text))
        
    return feature_bools

def convert_dictionary_to_dataset_for_gender(data_set,feature_words,sender):
    
    # test = generate_feature_data(data_set[0]["body"],feature_words)
    complete_data = []
    incomplete_data = []
    targets = []
    
    occupations = df["occupation"].unique()
    
    skip_occs = []
    for occ in occupations:
        dft = df[df["occupation"]==occ]
        
        if dft.shape[0] <= 10:
            skip_occs.append(occ)
            
    for dictionary in not_darwin_dict:
        free_text = dictionary["body"]
        try:
            person_id = dictionary[sender]
        except:
            print(dictionary)
            continue
        number_key = person_id[21:-4]

        boolean_set = generate_feature_data(free_text,feature_words)
        try:
            dft = df[df["id"]=="DCP-IDENT-"+str(number_key)]
            gender = dft["occupation"].iloc[0]
    #         if dft["name"].iloc[0] == "John Jenner Weir":
    #             print(gender)
            if gender == "no common occupation" or gender in skip_occs:
                incomplete_data.append(boolean_set)
                continue
    #             gender = "NotAvailable"
    #             print(number_key)
        except:
            continue
    #         gender = "NotAvailable"
    #         print(number_key)
    #         print(reciever_id)
    #         print(df[df["id"]=="DCP-IDENT-"+str(number_key)])

        complete_data.append(boolean_set)
        targets.append(gender)
        
    return complete_data,incomplete_data,targets

def file_to_features(filepath):
    
    with open(filepath, encoding="utf8") as f:
        lines = f.readlines()

    lines_cleaned = []
    for word in lines:
        word = word[:-1]
        if word not in stopwords.words():
            lines_cleaned.append(word)

    feature_words = lines_cleaned
    
    f.close()
    return feature_words

def generate_darwin_or_not_query(dict_list,feature_words):
    
    complete_data = []
    targets = []
    for dict_ in dict_list:
        
        free_text = dict_["body"]
        boolean_set = {word : word in free_text for word in feature_words}
        person_id = dict_["sender_bio"]
        number_key = person_id[21:-4]
        if number_key != "1":
            darwin = "No"
        else:
            darwin = "Yes"
        
        complete_data.append(boolean_set)
        targets.append(darwin)
        
    return complete_data,targets

# %%
path = "dcp-data/letters/"
files = os.listdir(path)
print(files[0],files[-1])
# to be commented out depending on who is running the code (lol) 
files = files[1:]
words_darwin = []
words_not_darwin = []

i = 0

not_darwin_dict = []

for file_target in files:
    dict_cur = extract_info(path+file_target)
    cur_words = words_not_darwin
    if "sender" in dict_cur.keys() and dict_cur["sender"] == "Darwin, C. R.":
        cur_words = words_darwin
    else:
        not_darwin_dict.append(dict_cur)
    text_tokens = word_tokenize(dict_cur["body"])

    for word in text_tokens:
        if len(word) == 1 and not(word in ["i","a"]):
            continue
        else:
            cur_words.append(word)
            
    i += 1
    print(round((i/len(files))*100,2),end="\r"*(i!=len(files)))

print("")
print("Analysis Finished")
print(f"When all words are extracted, we have got a dataset of {len(words_not_darwin)} words in letters TO Darwin")
print(f"When all words are extracted, we have got a dataset of {len(words_darwin)} words in letters FROM Darwin")
# Out:
# .ipynb_checkpoints DCP-LETT-9999.xml
# 100.0
# Analysis Finished
# When all words are extracted, we have got a dataset of 593478 words in letters TO Darwin
# When all words are extracted, we have got a dataset of 695012 words in letters FROM Darwin

# %%
unique_words = {}
for counter, word in enumerate(words_not_darwin):
    try:
        unique_words[word] += 1
    except KeyError:
        unique_words[word] = 1
    print(round(((counter+1)/len(words_not_darwin))*100,2),end="\r")

sorted_unique_words = {key: value for key, value in sorted(unique_words.items(), key=lambda item: item[1],reverse=True)}

#     print(list(sorted_unique_words.keys())[:1000])
feature_words_unclean = list(sorted_unique_words.keys())[:1000]
feature_words = []
for word in feature_words_unclean:
    if word not in stopwords.words():
        feature_words.append(word)
# feature_words = file_to_features("dump_not_darwin.txt")
# complete_data,targets = generate_darwin_or_not_query(not_darwin_dict,feature_words)
complete_data,incomplete_data,targets = convert_dictionary_to_dataset_for_gender(not_darwin_dict,feature_words,"sender_bio")
# Out:
# 100.0

# %%
unique_tags = {}
for val in targets:
    try:
        unique_tags[val] += 1
    except:
        unique_tags[val] = 1
        
print(unique_tags)

sorted_unique_words = {k: value for k, value in sorted(unique_tags.items(), key=lambda item: item[1],reverse=True)}

print(list(sorted_unique_words.values())[0]/sum(sorted_unique_words.values()))
# Out:
# {'publisher': 239, 'zoologist': 413, 'traveller': 103, 'botanist': 1306, 'philosopher': 25, 'naturalist': 358, 'politician': 115, 'mathematician': 146, 'civil servant': 91, 'clergyman': 254, 'journalist': 16, 'barrister': 54, 'entomologist': 179, 'printer': 1, 'anatomist': 43, 'jurist': 13, 'lawyer': 34, 'surveyor': 21, 'teacher': 9, 'explorer': 24, 'architect': 4, 'businessman': 12, 'naval officer': 73, 'orientalist': 6, 'banker': 183, 'mining engineer': 20, 'physicist': 23, 'author': 185, 'statesman': 17, 'geologist': 214, 'librarian': 6, 'bookseller': 12, 'mineralogist': 10, 'embryologist': 13, 'editor': 68, 'gardener': 26, 'palaeontologist': 101, 'chemist': 64, 'nurseryman': 23, 'physiologist': 71, 'schoolteacher': 25, 'anthropologist': 21, 'civil engineer': 28, 'poet': 8, 'army officer': 23, 'diplomat': 30, 'engineer': 11, 'writer': 110, 'pharmacist': 60, 'inventor': 2, 'solicitor': 25, 'administrator': 1, 'missionary': 9, 'merchant': 8, 'social reformer': 6, 'judge': 20, 'novelist': 11, 'man of letters': 6, 'astronomer': 3, 'farmer': 24, 'landowner': 9, 'painter': 1, 'ornithologist': 12, 'artist': 9, 'magistrate': 4, 'whig politician': 1, 'historian': 2, 'surgeon': 2, 'head of state': 3, 'physician': 5}
# 0.258409180846854

# %%
X_train, X_test, y_train, y_test = train_test_split(
    complete_data, targets, test_size=0.2, random_state=42, 
)

# %%
DTclassifier = SklearnClassifier(DecisionTreeClassifier(max_depth=10))
training_set = []
for i,feature_set in enumerate(X_train):
    temp_dict = {}
    for j,val in enumerate(feature_set):
        temp_dict[feature_words[j]] = val == 1
    training_set.append((temp_dict,y_train[i]))
DTclassifier.train(training_set)
# Out:
# <SklearnClassifier(DecisionTreeClassifier(max_depth=10))>

# %%
testing_set = []
for i,feature_set in enumerate(X_test):
    temp_dict = {}
    for j,val in enumerate(feature_set):
        temp_dict[feature_words[j]] = val == 1
    testing_set.append((temp_dict,y_test[i]))

# %%
print(nltk.classify.accuracy(DTclassifier,testing_set))
# Out:
# 0.26409495548961426

# %%
# classifier = nltk.NaiveBayesClassifier.train(training_set)
# print(nltk.classify.accuracy(classifier,testing_set))
print(classifier.show_most_informative_features(1500))
# Out:
# Most Informative Features
#                contained = True           whig p : botani =    518.5 : 1.0
#                     lord = True           whig p : botani =    222.2 : 1.0
#                    human = True           man of : botani =    207.4 : 1.0
#                      shd = True            judge : botani =    207.4 : 1.0
#                   larger = True           printe : botani =    172.8 : 1.0
#                  printed = True           printe : botani =    172.8 : 1.0
#                  amongst = True           painte : zoolog =    164.5 : 1.0
#                    hopes = True           painte : zoolog =    164.5 : 1.0
#                 intended = True           printe : zoolog =    164.5 : 1.0
#                     feet = True           head o : botani =    155.6 : 1.0
#                 although = True           physic : botani =    148.1 : 1.0
#                     gone = True           painte : natura =    137.5 : 1.0
#                     says = True           printe : natura =    137.5 : 1.0
#                condition = True           surgeo : zoolog =    109.7 : 1.0
#                  journal = True           histor : zoolog =    109.7 : 1.0
#                    paris = True           surgeo : zoolog =    109.7 : 1.0
#                 peculiar = True           invent : zoolog =    109.7 : 1.0
#               researches = True           histor : zoolog =    109.7 : 1.0
#             accompanying = True           whig p : botani =    103.7 : 1.0
#                  females = True           jurist : botani =    103.7 : 1.0
#                    males = True           jurist : botani =    103.7 : 1.0
#                 anything = True           painte : publis =     99.5 : 1.0
#            circumstances = True           printe : publis =     99.5 : 1.0
#                   manner = True           whig p : publis =     99.5 : 1.0
#                 question = True           painte : publis =     99.5 : 1.0
#                     said = True           painte : publis =     99.5 : 1.0
#               scientific = True           painte : publis =     99.5 : 1.0
#                     paid = True           surgeo : botani =     94.3 : 1.0
#                 instance = True           invent : natura =     91.7 : 1.0
#                beautiful = True           physic : botani =     88.9 : 1.0
#                  history = True           missio : botani =     88.9 : 1.0
#                   sooner = True           astron : botani =     86.4 : 1.0
#                     j_ai = True           admini : geolog =     86.0 : 1.0
#                     home = True           head o : publis =     82.9 : 1.0
#                specimens = True           magist : publis =     82.9 : 1.0
#                      box = True           magist : zoolog =     82.2 : 1.0
#                   garden = True           astron : zoolog =     82.2 : 1.0
#                     lost = True           head o : zoolog =     82.2 : 1.0
#                 movement = True           astron : zoolog =     82.2 : 1.0
#                  receipt = True           magist : zoolog =     82.2 : 1.0
#                surprised = True           head o : zoolog =     82.2 : 1.0
#              communicate = True           whig p : botani =     81.9 : 1.0
#                 occurred = True           invent : botani =     79.8 : 1.0
#                   pardon = True           journa : botani =     79.8 : 1.0
#                   habits = True           mercha : botani =     77.8 : 1.0
#                    among = True           painte : banker =     72.5 : 1.0
#                   future = True           printe : banker =     72.5 : 1.0
#                    proof = True           printe : entomo =     72.0 : 1.0
#                 obtained = True           head o : botani =     70.7 : 1.0
#                receiving = True           head o : botani =     70.7 : 1.0
#                   museum = True           pharma : botani =     70.5 : 1.0
#                   cheque = True           states : zoolog =     70.5 : 1.0
#                  brother = True           painte : zoolog =     70.5 : 1.0
#                character = True           painte : zoolog =     70.5 : 1.0
#                     size = True           printe : zoolog =     70.5 : 1.0
#                     plus = True           surgeo : clergy =     69.3 : 1.0
#                    royal = True           physic : clergy =     69.3 : 1.0
#                    views = True           man of : clergy =     69.3 : 1.0
#                     bird = True           man of : botani =     69.1 : 1.0
#                    birds = True           man of : botani =     69.1 : 1.0
#                 distance = True            judge : botani =     69.1 : 1.0
#                  numbers = True           archit : botani =     69.1 : 1.0
#                   struck = True           histor : botani =     69.1 : 1.0
#                     date = True           astron : natura =     68.8 : 1.0
#                   passed = True           head o : natura =     68.8 : 1.0
#                   wanted = True           magist : natura =     68.8 : 1.0
#               considered = True           mercha : zoolog =     68.5 : 1.0
#                   leaves = True           archit : author =     68.1 : 1.0
#                    leave = True           archit : entomo =     67.2 : 1.0
#                    bring = True           invent : publis =     66.3 : 1.0
#                difficult = True           invent : publis =     66.3 : 1.0
#               difficulty = True           invent : publis =     66.3 : 1.0
#               especially = True           histor : publis =     66.3 : 1.0
#                     hard = True           surgeo : publis =     66.3 : 1.0
#                  insects = True           archit : publis =     66.3 : 1.0
#                knowledge = True           histor : publis =     66.3 : 1.0
#                   moment = True           surgeo : publis =     66.3 : 1.0
#                    night = True           invent : publis =     66.3 : 1.0
#                   others = True           invent : publis =     66.3 : 1.0
#                  special = True           histor : publis =     66.3 : 1.0
#                   summer = True           invent : publis =     66.3 : 1.0
#                 examined = True           archit : zoolog =     65.8 : 1.0
#               experience = True           orient : zoolog =     65.8 : 1.0
#                     leaf = True           archit : zoolog =     65.8 : 1.0
#                  passage = True           histor : zoolog =     65.8 : 1.0
#               permission = True           man of : zoolog =     65.8 : 1.0
#                 promised = True           physic : zoolog =     65.8 : 1.0
#                   really = True           physic : zoolog =     65.8 : 1.0
#                    times = True           archit : zoolog =     65.8 : 1.0
#                 tomorrow = True           archit : zoolog =     65.8 : 1.0
#                 darwin_s = True           landow : botani =     62.2 : 1.0
#              exceedingly = True           invent : botani =     61.0 : 1.0
#                    large = True           printe : publis =     59.7 : 1.0
#                   person = True           painte : publis =     59.7 : 1.0
#                    small = True           printe : publis =     59.7 : 1.0
#                    thing = True           painte : publis =     59.7 : 1.0
#                  species = True           artist : banker =     59.1 : 1.0
#                     bien = True           surgeo : geolog =     57.3 : 1.0
#               difference = True           invent : geolog =     57.3 : 1.0
#                 position = True           surgeo : geolog =     57.3 : 1.0
#                   seemed = True           man of : botani =     56.6 : 1.0
#                sometimes = True           archit : botani =     56.6 : 1.0
#                statement = True           orient : botani =     56.6 : 1.0
#                     glad = True           whig p : mathem =     56.5 : 1.0
#                     feel = True           social : publis =     55.3 : 1.0
#                 evidence = True           invent : natura =     55.0 : 1.0
#                  lecture = True           surgeo : natura =     55.0 : 1.0
#                   excuse = True           orient : natura =     55.0 : 1.0
#                  liberty = True           orient : natura =     55.0 : 1.0
#                 thinking = True           physic : natura =     55.0 : 1.0
#                    today = True           archit : natura =     55.0 : 1.0
#                    worms = True           archit : natura =     55.0 : 1.0
#                   pollen = True           landow : zoolog =     54.8 : 1.0
#                 valuable = True           social : zoolog =     54.8 : 1.0
#                   extent = True           artist : botani =     52.4 : 1.0
#                 original = True           head o : clergy =     52.0 : 1.0
#                     bees = True           magist : botani =     51.9 : 1.0
#                     body = True           head o : botani =     51.9 : 1.0
#                  opinion = True           teache : publis =     51.6 : 1.0
#                     room = True            judge : zoolog =     51.2 : 1.0
#                    least = True           painte : botani =     50.2 : 1.0
#                  brought = True           head o : publis =     49.8 : 1.0
#               containing = True           magist : publis =     49.8 : 1.0
#                 expected = True           head o : publis =     49.8 : 1.0
#                   father = True           head o : publis =     49.8 : 1.0
#                     fine = True           magist : publis =     49.8 : 1.0
#                   flower = True           bookse : publis =     49.8 : 1.0
#                     four = True           magist : publis =     49.8 : 1.0
#              immediately = True           head o : publis =     49.8 : 1.0
#              interesting = True           astron : publis =     49.8 : 1.0
#                      it— = True           head o : publis =     49.8 : 1.0
#                    known = True           magist : publis =     49.8 : 1.0
#                   latter = True           magist : publis =     49.8 : 1.0
#                    lower = True           bookse : publis =     49.8 : 1.0
#                  mention = True           astron : publis =     49.8 : 1.0
#                mentioned = True           astron : publis =     49.8 : 1.0
#                   regret = True           head o : publis =     49.8 : 1.0
#                  success = True           magist : publis =     49.8 : 1.0
#                   thanks = True           astron : publis =     49.8 : 1.0
#                    three = True           head o : publis =     49.8 : 1.0
#                 together = True           astron : publis =     49.8 : 1.0
#                     took = True           astron : publis =     49.8 : 1.0
#                   within = True           head o : publis =     49.8 : 1.0
#                    years = True           head o : publis =     49.8 : 1.0
#             satisfaction = True             poet : botani =     49.4 : 1.0
#               university = True            judge : botani =     49.4 : 1.0
#                     eyes = True           head o : zoolog =     49.4 : 1.0
#                  leaving = True           magist : zoolog =     49.4 : 1.0
#                    parts = True           head o : zoolog =     49.4 : 1.0
#                   season = True           magist : zoolog =     49.4 : 1.0
#                    visit = True           head o : zoolog =     49.4 : 1.0
#                   wishes = True           magist : zoolog =     49.4 : 1.0
#             observations = True           jurist : clergy =     48.5 : 1.0
#                     rate = True           painte : politi =     48.5 : 1.0
#                     wild = True           pharma : botani =     48.4 : 1.0
#                   except = True           invent : banker =     48.3 : 1.0
#                   friend = True           physic : banker =     48.3 : 1.0
#                   inform = True           surgeo : banker =     48.3 : 1.0
#                   notice = True           invent : banker =     48.3 : 1.0
#                    power = True           histor : banker =     48.3 : 1.0
#                     show = True           histor : banker =     48.3 : 1.0
#                      sir = True           surgeo : banker =     48.3 : 1.0
#                     used = True           invent : banker =     48.3 : 1.0
#                     done = True           man of : entomo =     48.0 : 1.0
#                   please = True           surgeo : entomo =     48.0 : 1.0
#                  suppose = True           invent : entomo =     48.0 : 1.0
#                professor = True           orient : botani =     47.9 : 1.0
#                   taking = True           man of : botani =     47.9 : 1.0
#                    party = True           social : botani =     47.1 : 1.0
#                 prepared = True           solici : botani =     47.1 : 1.0
#                 specimen = True           magist : mathem =     47.1 : 1.0
#                     hour = True           missio : zoolog =     47.0 : 1.0
#                   island = True           missio : zoolog =     47.0 : 1.0
#                  islands = True           missio : zoolog =     47.0 : 1.0
#                    means = True           invent : zoolog =     47.0 : 1.0
#                   strong = True           invent : zoolog =     47.0 : 1.0
#                  towards = True             poet : zoolog =     47.0 : 1.0
#                   either = True           landow : publis =     46.4 : 1.0
#                  neither = True           landow : natura =     45.8 : 1.0
#                     pray = True           minera : natura =     45.8 : 1.0
#               expression = True           astron : botani =     45.8 : 1.0
#                    reply = True           head o : botani =     45.8 : 1.0
#                 possibly = True           bookse : zoolog =     45.7 : 1.0
#                   spring = True           bookse : zoolog =     45.7 : 1.0
#                necessary = True           landow : botani =     44.4 : 1.0
#                  express = True           painte : banker =     43.5 : 1.0
#                     work = True           painte : banker =     43.5 : 1.0
#               afterwards = True           noveli : botani =     43.2 : 1.0
#                   report = True           mercha : botani =     43.2 : 1.0
#                    order = True           printe : entomo =     43.2 : 1.0
#                 possible = True           admini : entomo =     43.2 : 1.0
#                   desire = True           magist : geolog =     43.0 : 1.0
#             particularly = True           head o : geolog =     43.0 : 1.0
#                    south = True           diplom : zoolog =     42.9 : 1.0
#                      way = True           painte : publis =     42.6 : 1.0
#                 answered = True           physic : clergy =     41.6 : 1.0
#                 contains = True           man of : clergy =     41.6 : 1.0
#                    earth = True           archit : clergy =     41.6 : 1.0
#                  english = True           orient : clergy =     41.6 : 1.0
#                   unable = True           archit : clergy =     41.6 : 1.0
#                  animals = True           invent : botani =     41.5 : 1.0
#                answering = True           orient : botani =     41.5 : 1.0
#                 appeared = True           archit : botani =     41.5 : 1.0
#                   colour = True           archit : botani =     41.5 : 1.0
#                   mother = True           physic : botani =     41.5 : 1.0
#                    truth = True           orient : botani =     41.5 : 1.0
#                   indeed = True           noveli : publis =     41.5 : 1.0
#                    hands = True           head o : natura =     41.2 : 1.0
#                  looking = True           head o : natura =     41.2 : 1.0
#                     tho_ = True           head o : natura =     41.2 : 1.0
#                 probably = True           mercha : zoolog =     41.1 : 1.0
#              explanation = True           head o : botani =     40.9 : 1.0
#                     head = True           head o : botani =     40.9 : 1.0
#                  natural = True           magist : politi =     40.4 : 1.0
#                  descent = True             poet : botani =     40.4 : 1.0
#                     john = True           missio : botani =     40.4 : 1.0
#                  publish = True           whig p : civil  =     40.0 : 1.0
#                   female = True           jurist : botani =     39.9 : 1.0
#                     away = True           orient : publis =     39.8 : 1.0
#                      bad = True           physic : publis =     39.8 : 1.0
#                     bear = True           physic : publis =     39.8 : 1.0
#                      bed = True           archit : publis =     39.8 : 1.0
#                certainly = True           man of : publis =     39.8 : 1.0
#                     deal = True           man of : publis =     39.8 : 1.0
#                     high = True           invent : publis =     39.8 : 1.0
#                     line = True           invent : publis =     39.8 : 1.0
#                   merely = True           man of : publis =     39.8 : 1.0
#                      mrs = True           physic : publis =     39.8 : 1.0
#                     ones = True           orient : publis =     39.8 : 1.0
#                questions = True           orient : publis =     39.8 : 1.0
#                   reason = True           invent : publis =     39.8 : 1.0
#                  science = True           histor : publis =     39.8 : 1.0
#                  sending = True           archit : publis =     39.8 : 1.0
#                    speak = True           physic : publis =     39.8 : 1.0
#                  venture = True           man of : publis =     39.8 : 1.0
#                     word = True           man of : publis =     39.8 : 1.0
#                  bearing = True           physic : zoolog =     39.5 : 1.0
#                    wrong = True           orient : zoolog =     39.5 : 1.0
#                   regard = True           orient : natura =     39.3 : 1.0
#                   amount = True           missio : natura =     39.3 : 1.0
#                    death = True             poet : natura =     39.3 : 1.0
#                      due = True           missio : natura =     39.3 : 1.0
#                   friday = True           missio : natura =     39.3 : 1.0
#                       wd = True             poet : natura =     39.3 : 1.0
#                      cut = True           solici : geolog =     39.1 : 1.0
#                 occupied = True           mining : botani =     39.0 : 1.0
#                  flowers = True           bookse : publis =     38.7 : 1.0
#                variation = True           artist : clergy =     38.5 : 1.0
#                   winter = True           jurist : natura =     38.5 : 1.0
#                  _origin = True           artist : botani =     38.4 : 1.0
#                varieties = True           garden : natura =     37.5 : 1.0
#                    india = True           pharma : clergy =     37.4 : 1.0
#                     food = True           civil  : botani =     37.0 : 1.0
#                   honour = True           astron : botani =     37.0 : 1.0
#                   obtain = True           head o : botani =     37.0 : 1.0
#                   series = True           bookse : botani =     37.0 : 1.0
#                    study = True           teache : publis =     36.9 : 1.0
#                   author = True           orient : botani =     36.6 : 1.0
#                extremely = True           man of : botani =     36.6 : 1.0
#                forwarded = True           man of : botani =     36.6 : 1.0
#                  noticed = True           orient : botani =     36.6 : 1.0
#               impossible = True           artist : zoolog =     36.6 : 1.0
#                     knew = True            judge : zoolog =     36.6 : 1.0
#                    makes = True           teache : zoolog =     36.6 : 1.0
#                    names = True           artist : zoolog =     36.6 : 1.0
#                     poor = True            judge : zoolog =     36.6 : 1.0
#                    white = True           artist : zoolog =     36.6 : 1.0
#                  enclose = True           head o : author =     36.5 : 1.0
#                       yr = True           head o : author =     36.5 : 1.0
#                     _the = True           astron : banker =     36.2 : 1.0
#                   answer = True           head o : banker =     36.2 : 1.0
#                     days = True           head o : banker =     36.2 : 1.0
#                   expect = True           head o : banker =     36.2 : 1.0
#                     hand = True           head o : banker =     36.2 : 1.0
#                    heart = True           astron : banker =     36.2 : 1.0
#                  meeting = True           head o : banker =     36.2 : 1.0
#              opportunity = True           head o : banker =     36.2 : 1.0
#                     page = True           head o : banker =     36.2 : 1.0
#                  purpose = True           astron : banker =     36.2 : 1.0
#                  request = True           astron : banker =     36.2 : 1.0
#                 complete = True           head o : entomo =     36.0 : 1.0
#                     felt = True           astron : entomo =     36.0 : 1.0
#                  getting = True           head o : entomo =     36.0 : 1.0
#                    still = True           magist : entomo =     36.0 : 1.0
#                   origin = True           head o : entomo =     36.0 : 1.0
#                   animal = True           invent : botani =     35.8 : 1.0
#                    never = True           head o : publis =     35.5 : 1.0
#                  charles = True           mercha : botani =     35.4 : 1.0
#                     meet = True           head o : zoolog =     35.2 : 1.0
#                     land = True           mercha : publis =     34.8 : 1.0
#                expressed = True           busine : botani =     34.6 : 1.0
#                   voyage = True           minera : botani =     34.6 : 1.0
#                     real = True             poet : banker =     34.5 : 1.0
#                     fait = True           man of : geolog =     34.4 : 1.0
#                 remember = True           archit : geolog =     34.4 : 1.0
#               sufficient = True           orient : geolog =     34.4 : 1.0
#                     talk = True           physic : geolog =     34.4 : 1.0
#                     you— = True           physic : geolog =     34.4 : 1.0
#                   assure = True           mercha : natura =     34.4 : 1.0
#                  erasmus = True           mercha : natura =     34.4 : 1.0
#                   marked = True           mercha : natura =     34.4 : 1.0
#                     news = True           mercha : natura =     34.4 : 1.0
#                   period = True           mercha : natura =     34.4 : 1.0
#                   sunday = True           noveli : natura =     34.4 : 1.0
#                  chapter = True           missio : botani =     34.2 : 1.0
#                   family = True             poet : botani =     34.2 : 1.0
#                    fresh = True             poet : botani =     34.2 : 1.0
#                      six = True             poet : botani =     34.2 : 1.0
#                  society = True           physic : writer =     33.3 : 1.0
#                  arrived = True           social : publis =     33.2 : 1.0
#                  england = True           social : publis =     33.2 : 1.0
#                    heard = True           social : publis =     33.2 : 1.0
#                     hold = True           landow : publis =     33.2 : 1.0
#                    seems = True           social : publis =     33.2 : 1.0
#                    cause = True           printe : publis =     33.2 : 1.0
#                     even = True           printe : publis =     33.2 : 1.0
#                    state = True           whig p : publis =     33.2 : 1.0
#               interested = True           physic : natura =     33.0 : 1.0
#                     wife = True           physic : natura =     33.0 : 1.0
#                carefully = True           jurist : zoolog =     32.9 : 1.0
#             considerable = True           landow : zoolog =     32.9 : 1.0
#              experiments = True           minera : zoolog =     32.9 : 1.0
#                    hours = True           busine : zoolog =     32.9 : 1.0
#                   length = True           jurist : zoolog =     32.9 : 1.0
#                 produced = True           minera : zoolog =     32.9 : 1.0
#                     fact = True           invent : politi =     32.3 : 1.0
#                     mean = True           invent : politi =     32.3 : 1.0
#                  several = True           invent : politi =     32.3 : 1.0
#                      soc = True           physic : politi =     32.3 : 1.0
#                  variety = True           nurser : natura =     32.1 : 1.0
#                 somewhat = True           philos : botani =     32.0 : 1.0
#                     upon = True           pharma : banker =     31.9 : 1.0
#                     sort = True           artist : geolog =     31.9 : 1.0
#                    aware = True           teache : botani =     31.4 : 1.0
#                   french = True           artist : botani =     31.4 : 1.0
#                 scarcely = True           artist : botani =     31.4 : 1.0
#                   wished = True           embryo : botani =     31.4 : 1.0
#                      add = True           printe : banker =     31.1 : 1.0
#                    found = True           artist : publis =     31.0 : 1.0
#                   murray = True            judge : natura =     30.6 : 1.0
#                    value = True            judge : natura =     30.6 : 1.0
#                    world = True            judge : natura =     30.6 : 1.0
#                     male = True           jurist : botani =     30.5 : 1.0
#               geological = True           civil  : botani =     30.3 : 1.0
#                     left = True           mercha : banker =     30.2 : 1.0
#                      run = True           engine : publis =     30.2 : 1.0
#                   accept = True           magist : publis =     29.8 : 1.0
#                   people = True           head o : publis =     29.8 : 1.0
#              observation = True           histor : clergy =     29.7 : 1.0
#                 _descent = True             poet : clergy =     29.7 : 1.0
#                   sexual = True             poet : clergy =     29.7 : 1.0
#                according = True             poet : botani =     29.6 : 1.0
#                  college = True            judge : botani =     29.6 : 1.0
#                     july = True           missio : botani =     29.6 : 1.0
#                  matters = True           orient : botani =     29.6 : 1.0
#                  remarks = True           orient : botani =     29.6 : 1.0
#                sincerely = True           man of : botani =     29.6 : 1.0
#                   making = True           astron : natura =     29.5 : 1.0
#                     cold = True           physic : author =     29.2 : 1.0
#                  greater = True           orient : author =     29.2 : 1.0
#                   hardly = True           archit : author =     29.2 : 1.0
#                    north = True           physic : author =     29.2 : 1.0
#                  address = True           orient : banker =     29.0 : 1.0
#                   appear = True           archit : banker =     29.0 : 1.0
#                     help = True           orient : banker =     29.0 : 1.0
#                   kindly = True           physic : banker =     29.0 : 1.0
#                    might = True           man of : banker =     29.0 : 1.0
#                     miss = True           man of : banker =     29.0 : 1.0
#                    notes = True           physic : banker =     29.0 : 1.0
#                   object = True           man of : banker =     29.0 : 1.0
#                    offer = True           man of : banker =     29.0 : 1.0
#                     open = True           orient : banker =     29.0 : 1.0
#                   public = True           orient : banker =     29.0 : 1.0
#                    refer = True           man of : banker =     29.0 : 1.0
#                reference = True           man of : banker =     29.0 : 1.0
#                   remain = True           archit : banker =     29.0 : 1.0
#                  respect = True           man of : banker =     29.0 : 1.0
#                     true = True           orient : banker =     29.0 : 1.0
#                  various = True           physic : banker =     29.0 : 1.0
#                  engaged = True           bookse : botani =     28.8 : 1.0
#                    asked = True           physic : entomo =     28.8 : 1.0
#                   called = True           orient : entomo =     28.8 : 1.0
#                   coming = True           orient : entomo =     28.8 : 1.0
#                  reached = True           archit : entomo =     28.8 : 1.0
#                   review = True           man of : entomo =     28.8 : 1.0
#                  article = True           social : geolog =     28.7 : 1.0
#                   ground = True           minera : geolog =     28.7 : 1.0
#                   nearly = True           social : geolog =     28.7 : 1.0
#                    right = True           printe : geolog =     28.7 : 1.0
#                     seen = True           embryo : zoolog =     28.4 : 1.0
#                   always = True             poet : publis =     28.4 : 1.0
#                      ask = True           invent : publis =     28.4 : 1.0
#                  believe = True           librar : publis =     28.4 : 1.0
#                     case = True             poet : publis =     28.4 : 1.0
#                 distinct = True             poet : publis =     28.4 : 1.0
#                    forms = True           missio : publis =     28.4 : 1.0
#                    gives = True           librar : publis =     28.4 : 1.0
#                     keep = True           librar : publis =     28.4 : 1.0
#                     nice = True             poet : publis =     28.4 : 1.0
#                  subject = True           physic : publis =     28.4 : 1.0
#              translation = True           minera : botani =     28.3 : 1.0
#                  require = True           magist : mathem =     28.2 : 1.0
#                   asking = True           librar : zoolog =     28.2 : 1.0
#                  british = True           physic : zoolog =     28.2 : 1.0
#                   degree = True             poet : zoolog =     28.2 : 1.0
#                    field = True           missio : zoolog =     28.2 : 1.0
#                   former = True           physic : zoolog =     28.2 : 1.0
#                   health = True           man of : zoolog =     28.2 : 1.0
#                   months = True             poet : zoolog =     28.2 : 1.0
#                   points = True           physic : zoolog =     28.2 : 1.0
#                   things = True           archit : zoolog =     28.2 : 1.0
#                   useful = True           librar : zoolog =     28.2 : 1.0
#                    trust = True           orient : botani =     28.0 : 1.0
#                 kindness = True           bookse : entomo =     28.0 : 1.0
#                    comme = True           jurist : publis =     27.9 : 1.0
#                following = True           bookse : publis =     27.6 : 1.0
#                     year = True           head o : publis =     27.6 : 1.0
#                 greatest = True           landow : natura =     27.5 : 1.0
#                  absence = True           jurist : natura =     27.5 : 1.0
#                  allowed = True           landow : natura =     27.5 : 1.0
#                cambridge = True           landow : natura =     27.5 : 1.0
#                     kept = True           busine : natura =     27.5 : 1.0
#                     safe = True           jurist : natura =     27.5 : 1.0
#                   living = True           school : zoolog =     27.4 : 1.0
#                    tried = True           bookse : zoolog =     27.4 : 1.0
#                    would = True           painte : publis =     27.1 : 1.0
#                   action = True           physic : botani =     27.1 : 1.0
#                    genus = True           artist : author =     27.0 : 1.0
#                     view = True           man of : palaeo =     27.0 : 1.0
#                   huxley = True           philos : clergy =     27.0 : 1.0
#                     need = True             poet : mathem =     26.9 : 1.0
#                    going = True            judge : geolog =     26.8 : 1.0
#                  certain = True           man of : travel =     26.7 : 1.0
#                    facts = True           invent : travel =     26.7 : 1.0
#                    sexes = True           ornith : botani =     26.6 : 1.0
#                  propose = True           artist : botani =     26.6 : 1.0
#                   common = True           landow : mathem =     26.4 : 1.0
#                 children = True           solici : botani =     26.2 : 1.0
#                    comes = True           librar : botani =     26.1 : 1.0
#               respecting = True           missio : botani =     26.1 : 1.0
#                selection = True           anthro : botani =     26.1 : 1.0
#                  service = True           librar : botani =     26.1 : 1.0
#              description = True           noveli : botani =     25.9 : 1.0
#                  without = True           magist : banker =     25.9 : 1.0
#                  edition = True           mining : botani =     25.9 : 1.0
#                    given = True           survey : publis =     25.8 : 1.0
#                     herr = True           journa : publis =     25.5 : 1.0
#               altogether = True           survey : natura =     25.5 : 1.0
#                    learn = True           pharma : publis =     25.2 : 1.0
#                     less = True           painte : editor =     25.0 : 1.0
#                  receive = True           whig p : editor =     25.0 : 1.0
#                 received = True           whig p : editor =     25.0 : 1.0
#                     sent = True           printe : editor =     25.0 : 1.0
#                    shall = True           printe : editor =     25.0 : 1.0
#                    cases = True           archit : botani =     24.9 : 1.0
#                   almost = True           mercha : publis =     24.9 : 1.0
#                   change = True           mercha : publis =     24.9 : 1.0
#                     dear = True           mercha : publis =     24.9 : 1.0
#                   highly = True           mercha : publis =     24.9 : 1.0
#                   theory = True           noveli : publis =     24.9 : 1.0
#              publication = True           social : botani =     24.7 : 1.0
#                  country = True           mercha : zoolog =     24.7 : 1.0
#                   pretty = True           mercha : zoolog =     24.7 : 1.0
#                 referred = True           mercha : zoolog =     24.7 : 1.0
#                    brief = True           missio : geolog =     24.6 : 1.0
#                     busy = True           librar : geolog =     24.6 : 1.0
#                   chance = True           librar : geolog =     24.6 : 1.0
#                important = True             poet : geolog =     24.6 : 1.0
#                   copies = True           publis : botani =     24.6 : 1.0
#                       12 = True           jurist : author =     24.3 : 1.0
#                   hooker = True           magist : politi =     24.2 : 1.0
#                     know = True           magist : politi =     24.3 : 1.0
#                     late = True           magist : politi =     24.2 : 1.0
#                     next = True           head o : politi =     24.2 : 1.0
#                    often = True           head o : politi =     24.2 : 1.0
#                   plants = True           astron : politi =     24.2 : 1.0
#                   little = True           painte : banker =     24.2 : 1.0
#                  observe = True           jurist : banker =     24.2 : 1.0
#                  trouble = True           busine : banker =     24.2 : 1.0
#                    write = True           painte : banker =     24.2 : 1.0
#                    wrote = True           social : banker =     24.2 : 1.0
#                      yet = True           landow : banker =     24.2 : 1.0
#                    cross = True           landow : entomo =     24.0 : 1.0
#                    paper = True           printe : travel =     24.0 : 1.0
#                  pleased = True           social : entomo =     24.0 : 1.0
#                    black = True           landow : botani =     23.9 : 1.0
#                perfectly = True           bookse : geolog =     23.9 : 1.0
#                different = True           man of : publis =     23.9 : 1.0
#                   favour = True           physic : publis =     23.9 : 1.0
#                    place = True           physic : publis =     23.9 : 1.0
#                     race = True           archit : publis =     23.9 : 1.0
#                 returned = True           librar : writer =     23.8 : 1.0
#                 american = True           missio : natura =     23.6 : 1.0
#                    happy = True           physic : natura =     23.6 : 1.0
#              information = True           physic : natura =     23.6 : 1.0
#                     past = True           bookse : botani =     23.6 : 1.0
#                  feeling = True           social : zoolog =     23.5 : 1.0
#                     went = True           social : zoolog =     23.5 : 1.0
#                 business = True           mining : botani =     23.4 : 1.0
#                    close = True           head o : physio =     23.3 : 1.0
#                 interest = True             poet : publis =     23.3 : 1.0
#                    pages = True            judge : botani =     23.0 : 1.0
#                  greatly = True           physic : botani =     23.0 : 1.0
#               remarkable = True            judge : botani =     23.0 : 1.0
#                   sheets = True           palaeo : zoolog =     23.0 : 1.0
#                     hear = True           whig p : publis =     23.0 : 1.0
#                     list = True           artist : banker =     22.6 : 1.0
#                 observed = True           jurist : botani =     22.5 : 1.0
#                 occasion = True           landow : botani =     22.5 : 1.0
#               importance = True           explor : botani =     22.4 : 1.0
#                   direct = True            judge : entomo =     22.4 : 1.0
#                    worth = True            judge : entomo =     22.4 : 1.0
#                   trying = True           school : botani =     22.2 : 1.0
#                    truly = True           survey : botani =     22.2 : 1.0
#                  anxious = True           teache : publis =     22.1 : 1.0
#                   become = True            judge : publis =     22.1 : 1.0
#                   giving = True           embryo : publis =     22.1 : 1.0
#                    grand = True           anthro : publis =     22.1 : 1.0
#                    house = True            judge : publis =     22.1 : 1.0
#                  however = True           orient : publis =     22.1 : 1.0
#                   london = True            judge : publis =     22.1 : 1.0
#                   papers = True            judge : publis =     22.1 : 1.0
#                      put = True           physic : publis =     22.1 : 1.0
#                   single = True           artist : publis =     22.1 : 1.0
#                therefore = True           embryo : publis =     22.1 : 1.0
#                     told = True            judge : publis =     22.1 : 1.0
#                    young = True           teache : publis =     22.1 : 1.0
#                     dank = True           journa : geolog =     22.1 : 1.0
#                yesterday = True           solici : politi =     22.0 : 1.0
#                     gave = True            judge : zoolog =     21.9 : 1.0
#                    seeds = True           archit : zoolog =     21.9 : 1.0
#                    sorry = True           physic : zoolog =     21.9 : 1.0
#                    words = True           orient : zoolog =     21.9 : 1.0
#                    alone = True           teache : zoolog =     21.9 : 1.0
#                 enclosed = True           head o : author =     21.9 : 1.0
#                  knowing = True           engine : botani =     21.8 : 1.0
#               particular = True           head o : banker =     21.8 : 1.0
#                    fanny = True           civil  : botani =     21.6 : 1.0
#                      set = True           magist : entomo =     21.6 : 1.0
#                      etc = True           mercha : geolog =     21.5 : 1.0
#                     love = True             poet : botani =     21.2 : 1.0
#                 entirely = True           mining : geolog =     21.1 : 1.0
#               naturalist = True           magist : botani =     21.0 : 1.0
#                described = True           busine : clergy =     20.8 : 1.0
#                  growing = True           landow : clergy =     20.8 : 1.0
#                   growth = True           jurist : clergy =     20.8 : 1.0
#                    fancy = True           landow : botani =     20.7 : 1.0
#                  america = True           missio : banker =     20.7 : 1.0
#                   effect = True             poet : banker =     20.7 : 1.0
#                   genera = True           missio : banker =     20.7 : 1.0
#                  general = True           missio : banker =     20.7 : 1.0
#                     give = True           invent : banker =     20.7 : 1.0
#                     life = True             poet : banker =     20.7 : 1.0
#                    ready = True           missio : banker =     20.7 : 1.0
#                   result = True             poet : banker =     20.7 : 1.0
#                     town = True           librar : banker =     20.7 : 1.0
#               understand = True           librar : banker =     20.7 : 1.0
#                  morning = True           physic : geolog =     20.6 : 1.0
#                  perhaps = True           missio : entomo =     20.6 : 1.0
#                  reading = True           librar : entomo =     20.6 : 1.0
#                    short = True           librar : entomo =     20.6 : 1.0
#               photograph = True           diplom : botani =     20.5 : 1.0
#                      law = True           teache : botani =     20.3 : 1.0
#                    point = True           missio : publis =     20.3 : 1.0
#                  correct = True           physic : botani =     20.1 : 1.0
#                    agree = True           bookse : entomo =     20.0 : 1.0
#                      beg = True           head o : travel =     20.0 : 1.0
#                    ought = True           head o : travel =     20.0 : 1.0
#                   second = True           bookse : entomo =     20.0 : 1.0
#                     prof = True           orient : writer =     20.0 : 1.0
#                    reach = True           archit : writer =     20.0 : 1.0
#                      ago = True           landow : publis =     19.9 : 1.0
#                  evening = True           minera : publis =     19.9 : 1.0
#                otherwise = True           landow : publis =     19.9 : 1.0
#                   thinks = True           jurist : publis =     19.9 : 1.0
#                  tuesday = True           busine : publis =     19.9 : 1.0
#                  working = True           busine : publis =     19.9 : 1.0
#                      1st = True           landow : zoolog =     19.7 : 1.0
#                  instead = True           busine : zoolog =     19.7 : 1.0
#                      pay = True           states : natura =     19.6 : 1.0
#                      me— = True           social : natura =     19.6 : 1.0
#                   monday = True           states : natura =     19.6 : 1.0
#                    whose = True           states : natura =     19.6 : 1.0
#                    allow = True           orient : politi =     19.4 : 1.0
#                     call = True           orient : politi =     19.4 : 1.0
#                    doubt = True           orient : politi =     19.4 : 1.0
#                    fully = True           man of : politi =     19.4 : 1.0
#                   number = True           archit : politi =     19.4 : 1.0
#                     seed = True           archit : politi =     19.4 : 1.0
#                   seeing = True           survey : botani =     19.2 : 1.0
#                    tells = True           survey : botani =     19.2 : 1.0
#                    works = True           teache : geolog =     19.1 : 1.0
#                      old = True            judge : editor =     18.9 : 1.0
#                  exactly = True           engine : botani =     18.9 : 1.0
#                     idea = True           survey : entomo =     18.7 : 1.0
#                     like = True           invent : physio =     18.7 : 1.0
#                     fear = True            judge : publis =     18.6 : 1.0
#                    quite = True           social : publis =     18.4 : 1.0
#                     seem = True           social : publis =     18.4 : 1.0
#                   easily = True            judge : natura =     18.3 : 1.0
#                   fellow = True            judge : natura =     18.3 : 1.0
#                     kind = True           painte : naval  =     18.3 : 1.0
#               appearance = True           jurist : botani =     18.3 : 1.0
#                     dare = True           survey : zoolog =     18.3 : 1.0
#                     lady = True           survey : zoolog =     18.3 : 1.0
#                     dont = True           noveli : author =     18.2 : 1.0
#                    money = True           mining : botani =     18.2 : 1.0
#                  already = True           mercha : banker =     18.1 : 1.0
#                   darwin = True           mercha : banker =     18.1 : 1.0
#                  letters = True           noveli : banker =     18.1 : 1.0
#                    great = True           archit : publis =     18.1 : 1.0
#                     many = True           histor : publis =     18.1 : 1.0
#                   placed = True           engine : publis =     18.1 : 1.0
#                   though = True           orient : publis =     18.1 : 1.0
#                  account = True             poet : botani =     18.1 : 1.0
#                     half = True           noveli : entomo =     18.0 : 1.0
#                      vol = True           mercha : entomo =     18.0 : 1.0
#                     thus = True           artist : politi =     18.0 : 1.0
#                   nature = True           physic : clergy =     17.8 : 1.0
#                  present = True           mercha : naval  =     17.8 : 1.0
#                   likely = True           survey : botani =     17.5 : 1.0
#                   lately = True           mining : publis =     17.5 : 1.0
#                  similar = True           diplom : geolog =     17.4 : 1.0
#                  curious = True           nurser : clergy =     17.3 : 1.0
#                     best = True           landow : geolog =     17.2 : 1.0
#                    round = True           minera : geolog =     17.2 : 1.0
#                     rest = True             poet : publis =     17.1 : 1.0
#                    clear = True           orient : publis =     17.1 : 1.0
#                     full = True           man of : publis =     17.1 : 1.0
#                    prove = True           orient : publis =     17.1 : 1.0
#                  whether = True           librar : publis =     17.1 : 1.0
#                  written = True           librar : publis =     17.1 : 1.0
#                     book = True           painte : anatom =     17.0 : 1.0
#                       ms = True           printe : anatom =     17.0 : 1.0
#                     soon = True           astron : mathem =     16.9 : 1.0
#                      say = True           printe : physio =     16.8 : 1.0
#                 consider = True           mercha : travel =     16.7 : 1.0
#                published = True           social : writer =     16.7 : 1.0
#                     look = True           head o : publis =     16.6 : 1.0
# ...
#                   asking = False          publis : whig p =      1.3 : 1.0
#                attention = False          publis : whig p =      1.3 : 1.0
#                  besides = False          publis : whig p =      1.3 : 1.0
#                    brief = False          publis : whig p =      1.3 : 1.0
#                  brother = False          publis : whig p =      1.3 : 1.0
#                cambridge = False          publis : whig p =      1.3 : 1.0
#                     came = False          publis : whig p =      1.3 : 1.0
#                   chance = False          publis : whig p =      1.3 : 1.0
#                 children = False          publis : whig p =      1.3 : 1.0
#                    comes = False          publis : whig p =      1.3 : 1.0
#             considerable = False          publis : whig p =      1.3 : 1.0
#                  country = False          publis : whig p =      1.3 : 1.0
#                    death = False          publis : whig p =      1.3 : 1.0
#                   degree = False          publis : whig p =      1.3 : 1.0
#                delighted = False          publis : whig p =      1.3 : 1.0
#                described = False          publis : whig p =      1.3 : 1.0
#              description = False          publis : whig p =      1.3 : 1.0
#                    don_t = False          publis : whig p =      1.3 : 1.0
#                   effect = False          publis : whig p =      1.3 : 1.0
#                     else = False          publis : whig p =      1.3 : 1.0
#                  engaged = False          publis : whig p =      1.3 : 1.0
#                 entirely = False          publis : whig p =      1.3 : 1.0
#                      etc = False          publis : whig p =      1.3 : 1.0
#                  exactly = False          publis : whig p =      1.3 : 1.0
#               experiment = False          publis : whig p =      1.3 : 1.0
#              experiments = False          publis : whig p =      1.3 : 1.0
#                   family = False          publis : whig p =      1.3 : 1.0
#                    fancy = False          publis : whig p =      1.3 : 1.0
#                   fellow = False          publis : whig p =      1.3 : 1.0
#                   female = False          publis : whig p =      1.3 : 1.0
#                    fresh = False          publis : whig p =      1.3 : 1.0
#                     gave = False          publis : whig p =      1.3 : 1.0
#                     goes = False          publis : whig p =      1.3 : 1.0
#                 greatest = False          publis : whig p =      1.3 : 1.0
#                   ground = False          publis : whig p =      1.3 : 1.0
#                     grow = False          publis : whig p =      1.3 : 1.0
#                   growth = False          publis : whig p =      1.3 : 1.0
#                    hopes = False          publis : whig p =      1.3 : 1.0
#                     hour = False          publis : whig p =      1.3 : 1.0
#                    hours = False          publis : whig p =      1.3 : 1.0
#                   huxley = False          publis : whig p =      1.3 : 1.0
#                     idea = False          publis : whig p =      1.3 : 1.0
#               importance = False          publis : whig p =      1.3 : 1.0
#                important = False          publis : whig p =      1.3 : 1.0
#               impossible = False          publis : whig p =      1.3 : 1.0
#                influence = False          publis : whig p =      1.3 : 1.0
#                   island = False          publis : whig p =      1.3 : 1.0
#                  islands = False          publis : whig p =      1.3 : 1.0
#                     john = False          publis : whig p =      1.3 : 1.0
#                     kept = False          publis : whig p =      1.3 : 1.0
#                     knew = False          publis : whig p =      1.3 : 1.0
#                      law = False          publis : whig p =      1.3 : 1.0
#                   length = False          publis : whig p =      1.3 : 1.0
#                  letters = False          publis : whig p =      1.3 : 1.0
#                     life = False          publis : whig p =      1.3 : 1.0
#                   likely = False          publis : whig p =      1.3 : 1.0
#                    lines = False          publis : whig p =      1.3 : 1.0
#                   living = False          publis : whig p =      1.3 : 1.0
#                     male = False          publis : whig p =      1.3 : 1.0
#                    miles = False          publis : whig p =      1.3 : 1.0
#                     mind = False          publis : whig p =      1.3 : 1.0
#                  neither = False          publis : whig p =      1.3 : 1.0
#                     news = False          publis : whig p =      1.3 : 1.0
#                  nothing = False          publis : whig p =      1.3 : 1.0
#                  obliged = False          publis : whig p =      1.3 : 1.0
#                  observe = False          publis : whig p =      1.3 : 1.0
#                 observed = False          publis : whig p =      1.3 : 1.0
#                 occasion = False          publis : whig p =      1.3 : 1.0
#                  perfect = False          publis : whig p =      1.3 : 1.0
#                perfectly = False          publis : whig p =      1.3 : 1.0
#                 pleasant = False          publis : whig p =      1.3 : 1.0
#                  pleased = False          publis : whig p =      1.3 : 1.0
#                   pollen = False          publis : whig p =      1.3 : 1.0
#                 possibly = False          publis : whig p =      1.3 : 1.0
#                   pretty = False          publis : whig p =      1.3 : 1.0
#                 produced = False          publis : whig p =      1.3 : 1.0
#                  reading = False          publis : whig p =      1.3 : 1.0
#                 referred = False          publis : whig p =      1.3 : 1.0
#                  results = False          publis : whig p =      1.3 : 1.0
#                     room = False          publis : whig p =      1.3 : 1.0
#                    round = False          publis : whig p =      1.3 : 1.0
#                      saw = False          publis : whig p =      1.3 : 1.0
#                   saying = False          publis : whig p =      1.3 : 1.0
#                     says = False          publis : whig p =      1.3 : 1.0
#                 scarcely = False          publis : whig p =      1.3 : 1.0
#                selection = False          publis : whig p =      1.3 : 1.0
#                   series = False          publis : whig p =      1.3 : 1.0
#                    sexes = False          publis : whig p =      1.3 : 1.0
#                   sexual = False          publis : whig p =      1.3 : 1.0
#                    short = False          publis : whig p =      1.3 : 1.0
#                  similar = False          publis : whig p =      1.3 : 1.0
#                something = False          publis : whig p =      1.3 : 1.0
#                 somewhat = False          publis : whig p =      1.3 : 1.0
#                    south = False          publis : whig p =      1.3 : 1.0
#                   spring = False          publis : whig p =      1.3 : 1.0
#                   sunday = False          publis : whig p =      1.3 : 1.0
#                    tells = False          publis : whig p =      1.3 : 1.0
#                    tried = False          publis : whig p =      1.3 : 1.0
#                   trying = False          publis : whig p =      1.3 : 1.0
#               university = False          publis : whig p =      1.3 : 1.0
#                 valuable = False          publis : whig p =      1.3 : 1.0
#                varieties = False          publis : whig p =      1.3 : 1.0
#                    water = False          publis : whig p =      1.3 : 1.0
#                     went = False          publis : whig p =      1.3 : 1.0
#                 whatever = False          publis : whig p =      1.3 : 1.0
#                    white = False          publis : whig p =      1.3 : 1.0
#                wonderful = False          publis : whig p =      1.3 : 1.0
#                    world = False          publis : whig p =      1.3 : 1.0
#               afterwards = False          geolog : whig p =      1.3 : 1.0
#                  anxious = False          geolog : whig p =      1.3 : 1.0
#                 business = False          geolog : whig p =      1.3 : 1.0
#                     dare = False          geolog : whig p =      1.3 : 1.0
#                     dont = False          geolog : whig p =      1.3 : 1.0
#                  evening = False          geolog : whig p =      1.3 : 1.0
#                  orchids = False          geolog : whig p =      1.3 : 1.0
#                    pages = False          geolog : whig p =      1.3 : 1.0
#                      pay = False          geolog : whig p =      1.3 : 1.0
#                   placed = False          geolog : whig p =      1.3 : 1.0
#             satisfaction = False          geolog : whig p =      1.3 : 1.0
#                 saturday = False          geolog : whig p =      1.3 : 1.0
#                      six = False          geolog : whig p =      1.3 : 1.0
#                     size = False          geolog : whig p =      1.3 : 1.0
#                   voyage = False          geolog : whig p =      1.3 : 1.0
#                  working = False          geolog : whig p =      1.3 : 1.0
#                necessary = False          botani : whig p =      1.3 : 1.0
#                 prepared = False          botani : whig p =      1.3 : 1.0
#                  america = False          author : whig p =      1.3 : 1.0
#                   amount = False          author : whig p =      1.3 : 1.0
#                  appears = False          author : whig p =      1.3 : 1.0
#                     busy = False          author : whig p =      1.3 : 1.0
#                 distinct = False          author : whig p =      1.3 : 1.0
#                   report = False          author : whig p =      1.3 : 1.0
#                  _origin = False          banker : whig p =      1.3 : 1.0
#                according = False          banker : whig p =      1.3 : 1.0
#               appearance = False          banker : whig p =      1.3 : 1.0
#                  arrived = False          banker : whig p =      1.3 : 1.0
#                   assure = False          banker : whig p =      1.3 : 1.0
#                    aware = False          banker : whig p =      1.3 : 1.0
#                beginning = False          banker : whig p =      1.3 : 1.0
#                   beyond = False          banker : whig p =      1.3 : 1.0
#                    black = False          banker : whig p =      1.3 : 1.0
#                    books = False          banker : whig p =      1.3 : 1.0
#                carefully = False          banker : whig p =      1.3 : 1.0
#                   copies = False          banker : whig p =      1.3 : 1.0
#                     dear = False          banker : whig p =      1.3 : 1.0
#                    delay = False          banker : whig p =      1.3 : 1.0
#                  england = False          banker : whig p =      1.3 : 1.0
#                     fear = False          banker : whig p =      1.3 : 1.0
#                  friends = False          banker : whig p =      1.3 : 1.0
#                   german = False          banker : whig p =      1.3 : 1.0
#                    given = False          banker : whig p =      1.3 : 1.0
#                    gives = False          banker : whig p =      1.3 : 1.0
#                   giving = False          banker : whig p =      1.3 : 1.0
#                    grand = False          banker : whig p =      1.3 : 1.0
#                   highly = False          banker : whig p =      1.3 : 1.0
#                  knowing = False          banker : whig p =      1.3 : 1.0
#                   lately = False          banker : whig p =      1.3 : 1.0
#                    learn = False          banker : whig p =      1.3 : 1.0
#                   manner = False          banker : printe =      1.3 : 1.0
#                      me— = False          banker : whig p =      1.3 : 1.0
#                otherwise = False          banker : whig p =      1.3 : 1.0
#                     past = False          banker : whig p =      1.3 : 1.0
#                   period = False          banker : whig p =      1.3 : 1.0
#               photograph = False          banker : whig p =      1.3 : 1.0
#                     pray = False          banker : whig p =      1.3 : 1.0
#                  printed = False          banker : whig p =      1.3 : 1.0
#              publication = False          banker : whig p =      1.3 : 1.0
#                published = False          banker : whig p =      1.3 : 1.0
#                   theory = False          banker : whig p =      1.3 : 1.0
#                   volume = False          banker : whig p =      1.3 : 1.0
#                    whose = False          banker : whig p =      1.3 : 1.0
#                     wild = False          banker : whig p =      1.3 : 1.0
#                    works = False          banker : whig p =      1.3 : 1.0
#                  written = False          banker : whig p =      1.3 : 1.0
#                    young = False          banker : whig p =      1.3 : 1.0
#                      1st = False          entomo : whig p =      1.3 : 1.0
#                      due = False          entomo : whig p =      1.3 : 1.0
#                   future = False          entomo : whig p =      1.3 : 1.0
#                     hold = False          entomo : whig p =      1.3 : 1.0
#                   longer = False          entomo : whig p =      1.3 : 1.0
#                   sheets = False          entomo : whig p =      1.3 : 1.0
#                  towards = False          entomo : whig p =      1.3 : 1.0
#                  absence = False          mathem : whig p =      1.3 : 1.0
#                   afraid = False          mathem : whig p =      1.3 : 1.0
#                  curious = False          mathem : whig p =      1.3 : 1.0
#                    makes = False          zoolog : whig p =      1.3 : 1.0
#                 probably = False          zoolog : whig p =      1.3 : 1.0
#                   become = False          writer : whig p =      1.3 : 1.0
#                    field = False          writer : whig p =      1.3 : 1.0
#                   friday = False          writer : whig p =      1.3 : 1.0
#                   nearly = False          writer : whig p =      1.3 : 1.0
#                    agree = False          politi : whig p =      1.3 : 1.0
#                    begin = False          politi : whig p =      1.3 : 1.0
#               collection = False          politi : whig p =      1.3 : 1.0
#                    every = False          politi : whig p =      1.3 : 1.0
#                  instead = False          politi : whig p =      1.3 : 1.0
#                      run = False          politi : whig p =      1.3 : 1.0
#                     safe = False          politi : whig p =      1.3 : 1.0
#                   seeing = False          politi : whig p =      1.3 : 1.0
#                     told = False          politi : whig p =      1.3 : 1.0
#                    whole = False          politi : whig p =      1.3 : 1.0
#                    wrote = False          politi : whig p =      1.3 : 1.0
#                  descent = False          botani : whig p =      1.3 : 1.0
#                    value = False          natura : whig p =      1.3 : 1.0
#                   course = False          palaeo : whig p =      1.3 : 1.0
#                     keep = False          palaeo : whig p =      1.3 : 1.0
#                   looked = False          palaeo : whig p =      1.3 : 1.0
#                   unless = False          palaeo : whig p =      1.3 : 1.0
#                    usual = False          palaeo : whig p =      1.3 : 1.0
#                       12 = False          travel : whig p =      1.3 : 1.0
#                   almost = False          travel : whig p =      1.3 : 1.0
#                   change = False          civil  : whig p =      1.3 : 1.0
#                 finished = False          civil  : whig p =      1.3 : 1.0
# None

# %%
import plotly.graph_objects as go

# %%
print(DTclassifier.labels())
